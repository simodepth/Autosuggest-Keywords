# %% [markdown]
# <a href="https://colab.research.google.com/github/simodepth/Keyword-Research/blob/main/%F0%9F%A7%B9Query_Preprocessing_and_Spelling_Check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Query Preprocessing and spelling Check
#
#
# ---
#
#
# For each keyword in the list, we are going to run an Exploratory Data Analysis (EDA)aimed to detox low-value terms from large datasets
#
# In particular, the following lines of code will do:
#
# - **Singulars**: Create singular inflections of all words in the keyword
# - **Isomers**: Order words in the phrase alphabetically
# - **Spellcheck**: correct spelling of words in keywords
#
# ##Requirements
#
#
# ---
# - A file containing Keywords that can either be:
#   - A fresh list of queries from Google Autosuggest - that you can perform with Ecommercetools
#   - A CSV file with **only** keywords listed in the first column

# %%
# install additional python packages

# !pip install inflect
# !pip install fuzzywuzzy
# !pip install pyspellchecker
# !pip install python-Levenshtein
# !pip install ecommercetools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (0.18.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.7/dist-packages (0.7.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.7/dist-packages (0.20.7)
# Requirement already satisfied: Levenshtein==0.20.7 in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein) (0.20.7)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from Levenshtein==0.20.7->python-Levenshtein) (2.11.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ecommercetools in /usr/local/lib/python3.7/dist-packages (0.42.4)
# Requirement already satisfied: httplib2>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.17.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (4.23.1)
# Requirement already satisfied: pycausalimpact in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.21.6)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.10.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.12.1+cu113)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (2.23.0)
# Requirement already satisfied: gapandas in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (1.0)
# Requirement already satisfied: lifetimes in /usr/local/lib/python3.7/dist-packages (from ecommercetools) (0.11.3)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (4.1.3)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from gapandas->ecommercetools) (1.12.11)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (0.0.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.35.0)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.15.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->gapandas->ecommercetools) (1.31.6)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (21.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (57.4.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (2022.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (1.56.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (4.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<3dev,>=1.21.0->google-api-python-client->gapandas->ecommercetools) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client->gapandas->ecommercetools) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->ecommercetools) (2.10)
# Requirement already satisfied: dill>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (0.3.5.1)
# Requirement already satisfied: autograd>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lifetimes->ecommercetools) (1.7.3)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.2.0->lifetimes->ecommercetools) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ecommercetools) (2.8.2)
# Requirement already satisfied: statsmodels>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (0.12.2)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (2.11.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.7/dist-packages (from pycausalimpact->ecommercetools) (3.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.10->pycausalimpact->ecommercetools) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.2.3->pycausalimpact->ecommercetools) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=2.2.3->pycausalimpact->ecommercetools) (4.1.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.0->pycausalimpact->ecommercetools) (0.5.3)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (2.0.1)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (1.4.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (1.0.2)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (0.1.11)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->ecommercetools) (1.19.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.64.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (10.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->ecommercetools) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->ecommercetools) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->ecommercetools) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->ecommercetools) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->ecommercetools) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->ecommercetools) (3.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (3.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers->ecommercetools) (0.10.1)

# %%
import pandas as pd
import numpy as np
from ecommercetools import seo
import inflect
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from spellchecker import SpellChecker

# %%
#@title Scrape Google Autosuggest
suggestions = seo.google_autocomplete('coffee', include_expanded=True)
suggestions.to_csv('coffee.csv', index=False)
suggestions.head()
# Out:
#                         term  relevance
# 0             coffee near me       1250
# 1        cheap coffee tables       1250
# 2    when coffee meets bagel       1250
# 3  why coffee makes you poop       1250
# 4                coffee bean       1250

# %%
#@title Upload the File and Create a Pandas Data frame
file_path = pd.read_csv("/content/coffee.csv")
df = pd.DataFrame(file_path,columns=['term','relevance'])
df.columns = ['keyword', 'relevance']
df.columns = df.columns.str.lower()    # change col headers to lower case for compatibility
df.head()
# Out:
#                      keyword  relevance
# 0             coffee near me       1250
# 1        cheap coffee tables       1250
# 2    when coffee meets bagel       1250
# 3  why coffee makes you poop       1250
# 4                coffee bean       1250

# %%
p = inflect.engine()
spell = SpellChecker()

# functions to run on keywords
def singularise(keyword):
    s = ''
    keyword = str(keyword).split()
    for i in keyword:
        if p.singular_noun(i):
            s += f' {p.singular_noun(i)}'
        else:
            s += ' '+ i
    s = s.strip()
    return s

def isomerise(keyword):
    isomer = ' '.join(sorted(keyword.split(), key=str.lower))
    return isomer

def spellcheck(keyword):
    s = ''
    keyword = str(keyword).split()
    for i in keyword:
        s += f" {spell.correction(i)}"
    s = s.strip()
    return s

# remove keywords that've already been done
# (in case of error on previous runthrough)
try:
    incomplete = df[df["singular"].isin([np.nan])]
except KeyError:
    incomplete = df.copy()

# iterate through rows to get singulars, isomers and spellcheck for all keywords
for i in df.index:
    keyword = str(df["keyword"][i].strip())
    print(f"{i+1} of {len(df)} -", keyword)

    df.at[i, "keyword"] = keyword
    df.at[i, "singular"] = singularise(keyword)
    df.at[i, "isomer"] = isomerise(keyword)
    df.at[i, "spellcheck"] = spellcheck(keyword)
    if df["keyword"][i] == df["spellcheck"][i]:
        df.at[i,"spellcheck match"] = "yes"
    else:
        df.at[i,"spellcheck match"] = "no"

# save file
df.to_csv('keyword_normalization.csv', index=False)

print('DONE!')
# Out:
# 1 of 336 - coffee near me
# 2 of 336 - cheap coffee tables
# 3 of 336 - when coffee meets bagel
# 4 of 336 - why coffee makes you poop
# 5 of 336 - coffee bean
# 6 of 336 - coffee jelly
# 7 of 336 - coffee near me
# 8 of 336 - coffee quotes
# 9 of 336 - coffee shops near me
# 10 of 336 - coffee x change
# 11 of 336 - coffee zone
# 12 of 336 - when coffee and kale compete
# 13 of 336 - how coffee is made
# 14 of 336 - coffee house
# 15 of 336 - coffee table
# 16 of 336 - coffee places near me
# 17 of 336 - coffee urn
# 18 of 336 - worst coffee creamer
# 19 of 336 - coffee underground
# 20 of 336 - why coffee is bad for you
# 21 of 336 - coffee open near me
# 22 of 336 - coffee zone menu
# 23 of 336 - coffee klatch
# 24 of 336 - coffee jokes
# 25 of 336 - coffee liqueur
# 26 of 336 - coffee emoji
# 27 of 336 - cheap coffee maker
# 28 of 336 - cheap coffee near me
# 29 of 336 - coffee house near me
# 30 of 336 - worst coffee in the world
# 31 of 336 - is coffee good for you
# 32 of 336 - coffee jelly recipe
# 33 of 336 - coffee vs espresso
# 34 of 336 - coffee zone edinburg
# 35 of 336 - coffee grinder
# 36 of 336 - coffee yogurt
# 37 of 336 - how coffee is decaffeinated
# 38 of 336 - coffee cake
# 39 of 336 - coffee maker
# 40 of 336 - cheap coffee table books
# 41 of 336 - what coffee has the most caffeine
# 42 of 336 - how coffee was discovered
# 43 of 336 - coffee cake recipe
# 44 of 336 - coffee jobs
# 45 of 336 - coffee meets bagel
# 46 of 336 - coffee or die
# 47 of 336 - coffee roasters near me
# 48 of 336 - coffee x bread
# 49 of 336 - coffee york maine
# 50 of 336 - coffee nearby
